# %%
import numpy as np
import netCDF4
from VNP21IMGNRT_002 import VNP21IMGNRTGranule

# %%
filename = "~/data/VNP21IMG_NRT.A2025021.1018.002.2025021155440.nc"

# %%
granule = VNP21IMGNRTGranule(filename)
granule
# Out:
# {
#   "filename": "~/data/VNP21IMG_NRT.A2025021.1018.002.2025021155440.nc"
# }

# %%
granule.filename
# Out:
# '~/data/VNP21IMG_NRT.A2025021.1018.002.2025021155440.nc'

# %%
granule.filename_absolute
# Out:
# '/Users/gregoryhalverson/data/VNP21IMG_NRT.A2025021.1018.002.2025021155440.nc'

# %%
granule.filename_base
# Out:
# 'VNP21IMG_NRT.A2025021.1018.002.2025021155440.nc'

# %%
granule.swath
# Out:
# '1018'

# %%
granule.date_UTC
# Out:
# datetime.datetime(2025, 1, 21, 0, 0)

# %%
granule.swaths
# Out:
# ['VIIRS_I5_LST']

# %%
granule.variables
# Out:
# ['Emis_I5', 'Emis_I5_err', 'LST', 'LST_err', 'QC', 'View_angle']

# %%
granule.lat
# Out:
# array([[54.33631516, 54.33684158, 54.3373642 , ..., 47.68965149,
#         47.68586349, 47.68204498],
#        [54.3289299 , 54.32945633, 54.32998276, ..., 47.6832428 ,
#         47.67943954, 47.67566681],
#        [54.32154083, 54.32207108, 54.32260132, ..., 47.67683411,
#         47.67309189, 47.66934204],
#        ...,
#        [33.58222198, 33.58208084, 33.58193588, ..., 28.68618584,
#         28.68385506, 28.68149757],
#        [33.57483673, 33.57469559, 33.57455826, ..., 28.67971802,
#         28.67722893, 28.67486572],
#        [33.56745148, 33.56731415, 33.56717682, ..., 28.67288399,
#         28.6704216 , 28.66803169]], shape=(6464, 6400))

# %%
granule.lon
# Out:
# array([[-144.91571045, -144.90272522, -144.88973999, ..., -101.39957428,
#         -101.38977814, -101.37991333],
#        [-144.91479492, -144.90180969, -144.88883972, ..., -101.40502167,
#         -101.39518738, -101.38544464],
#        [-144.91387939, -144.90090942, -144.88792419, ..., -101.41046906,
#         -101.40078735, -101.39112854],
#        ...,
#        [-145.54718018, -145.53814697, -145.52912903, ..., -113.73674011,
#         -113.72887421, -113.72093201],
#        [-145.54751587, -145.53849792, -145.52946472, ..., -113.74114227,
#         -113.73273468, -113.72478485],
#        [-145.54786682, -145.53883362, -145.52980042, ..., -113.74427795,
#         -113.73600769, -113.72797394]], shape=(6464, 6400))

# %%
granule.QC

# %%
np.dtype(granule.QC)
# Out:
# dtype('uint16')

# %%
granule.cloud

# %%
granule.ST_K

# %%
granule.ST_C

# %%
granule.LST_err

# %%
granule.Emis_I5

# %%
granule.Emis_I5_err

# %%
granule.View_angle
